# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
INXdataset = pd.read_csv(r'/Users/blackmamba/Desktop/bepec.in/Employee Project/Data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv')

# %%
#Employee performance data set 
INXdataset
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
#performace as a factor of Age 
sns.lineplot(x = INXdataset['Age'], y = INXdataset['PerformanceRating'])

# %%
#performace as a factor of Gender
sns.lineplot(x = INXdataset['Gender'], y = INXdataset['PerformanceRating'])

# %%
#performace as a factor of Educational backgound
sns.lineplot(x = INXdataset['EducationBackground'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of Educational backgound
sns.lineplot(x = INXdataset['MaritalStatus'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of EmpDepartment
sns.lineplot(x = INXdataset['EmpDepartment'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of EmpJobRole
sns.lineplot(x = INXdataset['EmpJobRole'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of BusinessTravelFrequency
sns.lineplot(x = INXdataset['BusinessTravelFrequency'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of DistanceFromHome
sns.lineplot(x = INXdataset['DistanceFromHome'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of EmpEducationLevel
sns.lineplot(x = INXdataset['EmpEducationLevel'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of EmpRelationshipSatisfaction
sns.lineplot(x = INXdataset['EmpRelationshipSatisfaction'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of TotalWorkExperienceInYears
sns.lineplot(x = INXdataset['TotalWorkExperienceInYears'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of EmpRelationshipSatisfaction
sns.lineplot(x = INXdataset['EmpRelationshipSatisfaction'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of TrainingTimesLastYear
sns.lineplot(x = INXdataset['TrainingTimesLastYear'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of EmpWorkLifeBalance
sns.lineplot(x = INXdataset['EmpWorkLifeBalance'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of ExperienceYearsAtThisCompany
sns.lineplot(x = INXdataset['ExperienceYearsAtThisCompany'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of ExperienceYearsAtThisCompany
sns.lineplot(x = INXdataset['ExperienceYearsInCurrentRole'], y = INXdataset['PerformanceRating'])

# %%
##performace as a factor of YearsSinceLastPromotion
sns.lineplot(x = INXdataset['YearsSinceLastPromotion'], y = INXdataset['PerformanceRating'])

# %%
# performace as a factor of YearsWithCurrManager.
size, scale = 100,1
INXdataset = pd.Series(np.random.gamma(scale, size=size) ** 1.5)

INXdataset.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('performace as a factor of Years With Current Manager')
plt.xlabel('YearsWithCurrManager')
plt.ylabel('PerformanceRating')
plt.grid(axis='y', alpha=0.75)

# %%
##performace as a factor of Attrition
sns.lineplot(x = INXdataset['Attrition'], y = INXdataset['PerformanceRating'])
